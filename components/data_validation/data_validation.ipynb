# %%
import warnings
warnings.filterwarnings("ignore")

import pkg_resources
import importlib
importlib.reload(pkg_resources)

import tensorflow as tf
import tensorflow_data_validation as tfdv
print('TF version:', tf.__version__)
print('TFDV version:', tfdv.version.__version__)
from tensorflow_data_validation.utils.display_util import get_statistics_html
# Out:
# TF version: 2.6.2
# TFDV version: 1.3.0

# %%
import pandas as pd
from sklearn.model_selection import train_test_split

# %%
from components.data_extraction import fetch_data
df = fetch_data()

# %%
df.drop(['_id', 'title', 'url', 'post_date'], axis=1, inplace=True)

# %%
# remove unexpected values
df = df.loc[df['external_color'] != '-']
df = df.loc[df['internal_color'] != '-']
df = df.loc[df['fuels'] != '-']
df = df.loc[df['gearbox'] != '-']
df = df.loc[df['wheel_drive'] != '']
df = df.loc[df['wheel_drive'] != '4WD hoặc AWD']

# %%
train_df, test_df = train_test_split(df, train_size=0.9, shuffle=True, random_state=43, stratify=df['branch'])

# %%
train_df, val_df = train_test_split(train_df, train_size=0.85, shuffle=True, random_state=43, stratify=train_df['branch'])

# %%
print("Train size: {}".format(len(train_df)))
print("Val size: {}".format(len(val_df)))
print("Test size: {}".format(len(test_df)))
# Out:
# Train size: 22972
# Val size: 4055
# Test size: 3004

# %%
train_df.head()
# Out:
#        year  price         location         branch    model    origin  \
# 8711   2014  2850   Hà Nội           Mercedes Benz  S class  imported
# 5260   2015  548    Bà Rịa Vũng Tàu  Ford           Everest  domestic
# 30922  2015  445    Hà Nội           Kia            K3       domestic
# 7862   2016  1169   Hà Nội           Mercedes Benz  C class  domestic
# 20306  2008  278    Đồng Nai         Honda          Civic    domestic
#
#        km_driven external_color internal_color  num_seats     fuels  \
# 8711   38000      Đen            Kem            5          gasoline
# 5260   0          Đỏ             Nhiều màu      8          diesel
# 30922  82000      Đen            Đen            5          gasoline
# 7862   66000      Đen            Kem            5          gasoline
# 20306  0          Đen            Kem            5          gasoline
#
#        engine_capacity    gearbox wheel_drive car_type
# 8711   4.7              automatic  RWD         sedan
# 5260   2.5              automatic  RWD         suv
# 30922  2.0              automatic  FWD         sedan
# 7862   2.0              automatic  RWD         sedan
# 20306  1.8              automatic  FWD         sedan

# %%
train_stats = tfdv.generate_statistics_from_dataframe(dataframe=train_df)

# %%
tfdv.visualize_statistics(train_stats)
# Out:
# <iframe id='facets-iframe' width="100%" height="500px"></iframe>
#         <script>
#         facets_iframe = document.getElementById('facets-iframe');
#         facets_html = '<script src="https://cdnjs.cloudflare.com/ajax/libs/webcomponentsjs/1.3.3/webcomponents-lite.js"><\/script><link rel="import" href="https://raw.githubusercontent.com/PAIR-code/facets/master/facets-dist/facets-jupyter.html"><facets-overview proto-input="..."></facets-overview>';
#         facets_iframe.srcdoc = facets_html;
#          facets_iframe.id = "";
#          setTimeout(() => {
#            facets_iframe.setAttribute('height', facets_iframe.contentWindow.document.body.offsetHeight + 'px')
#          }, 1500)
#          </script>

# %%
schema = tfdv.infer_schema(statistics=train_stats)
tfdv.display_schema(schema=schema)
# Out:
#                      Type  Presence Valency            Domain
# Feature name
# 'year'             INT     required          -
# 'price'            INT     required          -
# 'location'         STRING  required          'location'
# 'branch'           STRING  required          'branch'
# 'model'            BYTES   required          -
# 'origin'           STRING  required          'origin'
# 'km_driven'        INT     required          -
# 'external_color'   STRING  required          'external_color'
# 'internal_color'   STRING  required          'internal_color'
# 'num_seats'        INT     required          -
# 'fuels'            STRING  required          'fuels'
# 'engine_capacity'  FLOAT   optional  single  -
# 'gearbox'          STRING  required          'gearbox'
# 'wheel_drive'      STRING  required          'wheel_drive'
# 'car_type'         STRING  required          'car_type'
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            Values
# Domain
# 'location'        'An Giang', 'Bà Rịa Vũng Tàu', 'Bình Dương', 'Bình Phước', 'Bình Thuận', 'Bình Định', 'Bạc Liêu', 'Bắc Giang', 'Bắc Kạn', 'Bắc Ninh', 'Bến Tre', 'Cao Bằng', 'Cà Mau', 'Cần Thơ', 'Gia Lai', 'Hà Giang', 'Hà Nam', 'Hà Nội', 'Hà Tĩnh', 'Hòa Bình', 'Hưng Yên', 'Hải Dương', 'Hải Phòng', 'Hậu Giang', 'Khánh Hòa', 'Kiên Giang', 'Kon Tum', 'Lai Châu', 'Long An', 'Lào Cai', 'Lâm Đồng', 'Lạng Sơn', 'Nam Định', 'Nghệ An', 'Ninh Bình', 'Ninh Thuận', 'Phú Thọ', 'Phú Yên', 'Quảng Bình', 'Quảng Nam', 'Quảng Ngãi', 'Quảng Ninh', 'Quảng Trị', 'Sóc Trăng', 'Sơn La', 'TP HCM', 'Thanh Hóa', 'Thái Bình', 'Thái Nguyên', 'Thừa Thiên Huế', 'Tiền Giang', 'Trà Vinh', 'Tuyên Quang', 'Tây Ninh', 'Vĩnh Long', 'Vĩnh Phúc', 'Yên Bái', 'Điện Biên', 'Đà Nẵng', 'Đăk Lăk', 'Đăk Nông', 'Đồng Nai', 'Đồng Tháp'
# 'branch'          'Acura', 'Audi', 'BMW', 'Chevrolet', 'Daewoo', 'Ford', 'Honda', 'Hyundai', 'Isuzu', 'Kia', 'LandRover', 'Lexus', 'MG', 'Mazda', 'Mercedes Benz', 'Mini', 'Mitsubishi', 'Nissan', 'Peugeot', 'Porsche', 'Subaru', 'Suzuki', 'Toyota', 'VinFast', 'Volkswagen', 'Volvo'
# 'origin'          'domestic', 'imported'
# 'external_color'  'Bạc', 'Cam', 'Cát', 'Ghi', 'Hồng', 'Kem', 'Màu khác', 'Nhiều màu', 'Nâu', 'Trắng', 'Tím', 'Vàng', 'Xanh', 'Xám', 'Đen', 'Đỏ', 'Đồng'
# 'internal_color'  'Bạc', 'Cam', 'Cát', 'Ghi', 'Hồng', 'Kem', 'Màu khác', 'Nhiều màu', 'Nâu', 'Trắng', 'Tím', 'Vàng', 'Xanh', 'Xám', 'Đen', 'Đỏ', 'Đồng'
# 'fuels'           'diesel', 'electric', 'gasoline', 'hybrid'
# 'gearbox'         'Số hỗn hợp', 'automatic', 'manual'
# 'wheel_drive'     '4WD', 'AWD', 'FWD', 'RWD'
# 'car_type'        'convertible', 'coupe', 'crossover', 'hatchback', 'pickup', 'sedan', 'suv', 'truck', 'van', 'wagon'

# %%
schema_result = tfdv.utils.display_util.get_schema_dataframe(schema=schema)

# %%
schema_result[0]
# Out:
#                      Type  Presence Valency            Domain
# Feature name
# 'year'             INT     required          -
# 'price'            INT     required          -
# 'location'         STRING  required          'location'
# 'branch'           STRING  required          'branch'
# 'model'            BYTES   required          -
# 'origin'           STRING  required          'origin'
# 'km_driven'        INT     required          -
# 'external_color'   STRING  required          'external_color'
# 'internal_color'   STRING  required          'internal_color'
# 'num_seats'        INT     required          -
# 'fuels'            STRING  required          'fuels'
# 'engine_capacity'  FLOAT   optional  single  -
# 'gearbox'          STRING  required          'gearbox'
# 'wheel_drive'      STRING  required          'wheel_drive'
# 'car_type'         STRING  required          'car_type'

# %%
schema_result[1]
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            Values
# Domain
# 'location'        'An Giang', 'Bà Rịa Vũng Tàu', 'Bình Dương', 'Bình Phước', 'Bình Thuận', 'Bình Định', 'Bạc Liêu', 'Bắc Giang', 'Bắc Kạn', 'Bắc Ninh', 'Bến Tre', 'Cao Bằng', 'Cà Mau', 'Cần Thơ', 'Gia Lai', 'Hà Giang', 'Hà Nam', 'Hà Nội', 'Hà Tĩnh', 'Hòa Bình', 'Hưng Yên', 'Hải Dương', 'Hải Phòng', 'Hậu Giang', 'Khánh Hòa', 'Kiên Giang', 'Kon Tum', 'Lai Châu', 'Long An', 'Lào Cai', 'Lâm Đồng', 'Lạng Sơn', 'Nam Định', 'Nghệ An', 'Ninh Bình', 'Ninh Thuận', 'Phú Thọ', 'Phú Yên', 'Quảng Bình', 'Quảng Nam', 'Quảng Ngãi', 'Quảng Ninh', 'Quảng Trị', 'Sóc Trăng', 'Sơn La', 'TP HCM', 'Thanh Hóa', 'Thái Bình', 'Thái Nguyên', 'Thừa Thiên Huế', 'Tiền Giang', 'Trà Vinh', 'Tuyên Quang', 'Tây Ninh', 'Vĩnh Long', 'Vĩnh Phúc', 'Yên Bái', 'Điện Biên', 'Đà Nẵng', 'Đăk Lăk', 'Đăk Nông', 'Đồng Nai', 'Đồng Tháp'
# 'branch'          'Acura', 'Audi', 'BMW', 'Chevrolet', 'Daewoo', 'Ford', 'Honda', 'Hyundai', 'Isuzu', 'Kia', 'LandRover', 'Lexus', 'MG', 'Mazda', 'Mercedes Benz', 'Mini', 'Mitsubishi', 'Nissan', 'Peugeot', 'Porsche', 'Subaru', 'Suzuki', 'Toyota', 'VinFast', 'Volkswagen', 'Volvo'
# 'origin'          'domestic', 'imported'
# 'external_color'  'Bạc', 'Cam', 'Cát', 'Ghi', 'Hồng', 'Kem', 'Màu khác', 'Nhiều màu', 'Nâu', 'Trắng', 'Tím', 'Vàng', 'Xanh', 'Xám', 'Đen', 'Đỏ', 'Đồng'
# 'internal_color'  'Bạc', 'Cam', 'Cát', 'Ghi', 'Hồng', 'Kem', 'Màu khác', 'Nhiều màu', 'Nâu', 'Trắng', 'Tím', 'Vàng', 'Xanh', 'Xám', 'Đen', 'Đỏ', 'Đồng'
# 'fuels'           'diesel', 'electric', 'gasoline', 'hybrid'
# 'gearbox'         'Số hỗn hợp', 'automatic', 'manual'
# 'wheel_drive'     '4WD', 'AWD', 'FWD', 'RWD'
# 'car_type'        'convertible', 'coupe', 'crossover', 'hatchback', 'pickup', 'sedan', 'suv', 'truck', 'van', 'wagon'

# %%
result2 = schema_result[1]

# %%
result2.reset_index()
# Out:
#              Domain  \
# 0  'location'
# 1  'branch'
# 2  'origin'
# 3  'external_color'
# 4  'internal_color'
# 5  'fuels'
# 6  'gearbox'
# 7  'wheel_drive'
# 8  'car_type'
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             Values
# 0  'An Giang', 'Bà Rịa Vũng Tàu', 'Bình Dương', 'Bình Phước', 'Bình Thuận', 'Bình Định', 'Bạc Liêu', 'Bắc Giang', 'Bắc Kạn', 'Bắc Ninh', 'Bến Tre', 'Cao Bằng', 'Cà Mau', 'Cần Thơ', 'Gia Lai', 'Hà Giang', 'Hà Nam', 'Hà Nội', 'Hà Tĩnh', 'Hòa Bình', 'Hưng Yên', 'Hải Dương', 'Hải Phòng', 'Hậu Giang', 'Khánh Hòa', 'Kiên Giang', 'Kon Tum', 'Lai Châu', 'Long An', 'Lào Cai', 'Lâm Đồng', 'Lạng Sơn', 'Nam Định', 'Nghệ An', 'Ninh Bình', 'Ninh Thuận', 'Phú Thọ', 'Phú Yên', 'Quảng Bình', 'Quảng Nam', 'Quảng Ngãi', 'Quảng Ninh', 'Quảng Trị', 'Sóc Trăng', 'Sơn La', 'TP HCM', 'Thanh Hóa', 'Thái Bình', 'Thái Nguyên', 'Thừa Thiên Huế', 'Tiền Giang', 'Trà Vinh', 'Tuyên Quang', 'Tây Ninh', 'Vĩnh Long', 'Vĩnh Phúc', 'Yên Bái', 'Điện Biên', 'Đà Nẵng', 'Đăk Lăk', 'Đăk Nông', 'Đồng Nai', 'Đồng Tháp'
# 1  'Acura', 'Audi', 'BMW', 'Chevrolet', 'Daewoo', 'Ford', 'Honda', 'Hyundai', 'Isuzu', 'Kia', 'LandRover', 'Lexus', 'MG', 'Mazda', 'Mercedes Benz', 'Mini', 'Mitsubishi', 'Nissan', 'Peugeot', 'Porsche', 'Subaru', 'Suzuki', 'Toyota', 'VinFast', 'Volkswagen', 'Volvo'
# 2  'domestic', 'imported'
# 3  'Bạc', 'Cam', 'Cát', 'Ghi', 'Hồng', 'Kem', 'Màu khác', 'Nhiều màu', 'Nâu', 'Trắng', 'Tím', 'Vàng', 'Xanh', 'Xám', 'Đen', 'Đỏ', 'Đồng'
# 4  'Bạc', 'Cam', 'Cát', 'Ghi', 'Hồng', 'Kem', 'Màu khác', 'Nhiều màu', 'Nâu', 'Trắng', 'Tím', 'Vàng', 'Xanh', 'Xám', 'Đen', 'Đỏ', 'Đồng'
# 5  'diesel', 'electric', 'gasoline', 'hybrid'
# 6  'Số hỗn hợp', 'automatic', 'manual'
# 7  '4WD', 'AWD', 'FWD', 'RWD'
# 8  'convertible', 'coupe', 'crossover', 'hatchback', 'pickup', 'sedan', 'suv', 'truck', 'van', 'wagon'

# %%
import wandb
run = wandb.init(project="mlops-test", job_type="infer-skema")


# Log to the same named artifact, but with updated data
artifact = wandb.Artifact('categorical-schema', type='Schema')
schema = wandb.Table(data=schema_result[1])
artifact.add(schema, 'categorical-schema-table')

run.log_artifact(artifact)

# Now you have a new artifact version logged!

wandb.finish()
# Out:
# Tracking run with wandb version 0.12.17
# Run data is saved locally in <code>/home/phamvanhanh/PycharmProjects/MLOps-Capstone-Project/components/data_validation/wandb/run-20220602_222904-1uepb4sd</code>
# Syncing run <strong><a href="https://wandb.ai/phamvanhanh6720/mlops-test/runs/1uepb4sd" target="_blank">cool-microwave-16</a></strong> to <a href="https://wandb.ai/phamvanhanh6720/mlops-test" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='0.003 MB of 0.003 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, max…
# Synced <strong style="color:#cdcd00">cool-microwave-16</strong>: <a href="https://wandb.ai/phamvanhanh6720/mlops-test/runs/1uepb4sd" target="_blank">https://wandb.ai/phamvanhanh6720/mlops-test/runs/1uepb4sd</a><br/>Synced 4 W&B file(s), 0 media file(s), 1 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20220602_222904-1uepb4sd/logs</code>

# %%
eva_stats = tfdv.generate_statistics_from_dataframe(dataframe=val_df)

tfdv.visualize_statistics(lhs_statistics=eva_stats,
                          rhs_statistics=train_stats,
                          lhs_name='VAL_DATASET',
                          rhs_name='TRAIN_DATASET')
# Out:
# <iframe id='facets-iframe' width="100%" height="500px"></iframe>
#         <script>
#         facets_iframe = document.getElementById('facets-iframe');
#         facets_html = '<script src="https://cdnjs.cloudflare.com/ajax/libs/webcomponentsjs/1.3.3/webcomponents-lite.js"><\/script><link rel="import" href="https://raw.githubusercontent.com/PAIR-code/facets/master/facets-dist/facets-jupyter.html"><facets-overview proto-input="..."></facets-overview>';
#         facets_iframe.srcdoc = facets_html;
#          facets_iframe.id = "";
#          setTimeout(() => {
#            facets_iframe.setAttribute('height', facets_iframe.contentWindow.document.body.offsetHeight + 'px')
#          }, 1500)
#          </script>

# %%
file = get_statistics_html(lhs_statistics=eva_stats,
                          rhs_statistics=train_stats,
                          lhs_name='VAL_DATASET',
                          rhs_name='TRAIN_DATASET')

# %%
import wandb
run = wandb.init(project="mlops-test", job_type="statistic")

# Log to the same named artifact, but with updated data
artifact = wandb.Artifact('statistic', type='Statistic')
html = wandb.Html(data=file)
artifact.add(html, 'Statistic')
run.log_artifact(artifact)
# Now you have a new artifact version logged!

wandb.finish()
# Out:
# Tracking run with wandb version 0.12.17
# Run data is saved locally in <code>/home/phamvanhanh/PycharmProjects/MLOps-Capstone-Project/components/data_validation/wandb/run-20220602_230632-3oauvlcc</code>
# Syncing run <strong><a href="https://wandb.ai/phamvanhanh6720/mlops-test/runs/3oauvlcc" target="_blank">eager-blaze-17</a></strong> to <a href="https://wandb.ai/phamvanhanh6720/mlops-test" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='0.056 MB of 0.056 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, max…
# Synced <strong style="color:#cdcd00">eager-blaze-17</strong>: <a href="https://wandb.ai/phamvanhanh6720/mlops-test/runs/3oauvlcc" target="_blank">https://wandb.ai/phamvanhanh6720/mlops-test/runs/3oauvlcc</a><br/>Synced 4 W&B file(s), 0 media file(s), 2 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20220602_230632-3oauvlcc/logs</code>

# %%
anomalies = tfdv.validate_statistics(
    statistics=eva_stats,
    schema=schema
)

# %%
tfdv.display_anomalies(anomalies=anomalies)
# Out:
# <h4 style="color:green;">No anomalies found.</h4>

# %%
serving_stats = tfdv.generate_statistics_from_dataframe(test_df)

serving_anomalies = tfdv.validate_statistics(serving_stats, schema)

tfdv.display_anomalies(serving_anomalies)
# Out:
# <h4 style="color:green;">No anomalies found.</h4>

# %%
result = tfdv.utils.display_util.get_anomalies_dataframe(anomalies)

# %%
tfdv.write_anomalies_text(anomalies, 'test.txt')

# %%
tfdv.get_feature(schema, 'car_type').skew_comparator.infinity_norm.threshold = 0.03

skew_anomalies = tfdv.validate_statistics(
    statistics=train_stats,
    schema=schema,
    serving_statistics=serving_stats
)

# %%
tfdv.display_anomalies(skew_anomalies)
# Out:
# <h4 style="color:green;">No anomalies found.</h4>
